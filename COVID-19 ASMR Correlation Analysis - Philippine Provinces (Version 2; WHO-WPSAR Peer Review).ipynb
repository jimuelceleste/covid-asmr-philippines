# %% [markdown]
# # COVID-19 ASMR Correlation Analysis - Philippine Provinces (Version 2)
#
# **NEW: COVID-19 Tests Performed / Population * 100,000**
#
# Age-Standardized Mortality Rates (ASMR) allows the ranking of geographical areas with varying age structures according to mortality rates. It is computed by setting a standard population and using its age distribution as the weight. ASMR eliminates the age confounder which is present in COVID-19 (biased against the elderly).
#
# The objective of this notebook are as follows:
# 1. Compute the correlation between ASMR and the following variables (province-level):
#     - Poverty Incidence
#     - Hospital Beds per 100,000 population
#     - Population Density
#     - Elderly Population
#     - COVID-19 Tests Performed **[NEW]**
# 2. Compute the P-value of the correlations found; And,
# 3. Visualize the correlation between variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
sns.set_context("paper")

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Poverty Incidence (2021)

# %%
poverty = pd.read_excel('../data/Poverty Incidence/Poverty Incidence Among Population 2021.xlsx', index_col=0)
poverty.head()
# Out:
#                   Poverty Incidence
# PROVINCE
# ABRA                           21.5
# AGUSAN DEL NORTE               30.8
# AGUSAN DEL SUR                 41.3
# AKLAN                          20.2
# ALBAY                          20.4

# %%
poverty = poverty.rename(columns={'Poverty Incidence': 'Poverty Incidence (2021)'})
poverty.head()
# Out:
#                   Poverty Incidence (2021)
# PROVINCE
# ABRA                                  21.5
# AGUSAN DEL NORTE                      30.8
# AGUSAN DEL SUR                        41.3
# AKLAN                                 20.2
# ALBAY                                 20.4

# %% [markdown]
# ### Hospital Beds per 100,000 population (2022)

# %%
beds = pd.read_excel('../data/Hospital Beds/hospital_beds_by_province_2022.xlsx', index_col=0)
beds.head()
# Out:
#                   private_beds  government_beds  total_beds  population  \
# PROVINCE
# ABRA                        41               50          91      250309
# AGUSAN DEL NORTE           348              250         598      757121
# AGUSAN DEL SUR              80              180         260      737991
# AKLAN                      305              300         605      612985
# ALBAY                      558              375         933     1372550
#
#                   beds_per_100000_private  beds_per_100000_government  \
# PROVINCE
# ABRA                            16.379755                   19.975311
# AGUSAN DEL NORTE                45.963591                   33.019821
# AGUSAN DEL SUR                  10.840241                   24.390541
# AKLAN                           49.756519                   48.940839
# ALBAY                           40.654257                   27.321409
#
#                   beds_per_100000_total
# PROVINCE
# ABRA                          36.355065
# AGUSAN DEL NORTE              78.983412
# AGUSAN DEL SUR                35.230782
# AKLAN                         98.697358
# ALBAY                         67.975666

# %%
beds = beds[['beds_per_100000_total']]
beds = beds.rename(columns={'beds_per_100000_total': 'Hospital Beds per 100k (2022)'})
beds.head()
# Out:
#                   Hospital Beds per 100k (2022)
# PROVINCE
# ABRA                                  36.355065
# AGUSAN DEL NORTE                      78.983412
# AGUSAN DEL SUR                        35.230782
# AKLAN                                 98.697358
# ALBAY                                 67.975666

# %% [markdown]
# ### Population Density (2020)

# %%
density = pd.read_excel('../data/Population Density/Population Density 2020.xlsx', index_col=0)
density.head()
# Out:
#           Population Density                Remarks
# PROVINCE
# NCR             21765.280692                    NaN
# ABRA               59.762317                    NaN
# APAYAO             27.622587                    NaN
# BENGUET           292.593195  Including Baguio City
# IFUGAO             79.257910                    NaN

# %%
density = density[['Population Density']].rename(columns={'Population Density': 'Population Density (2020)'})
density.head()
# Out:
#           Population Density (2020)
# PROVINCE
# NCR                    21765.280692
# ABRA                      59.762317
# APAYAO                    27.622587
# BENGUET                  292.593195
# IFUGAO                    79.257910

# %% [markdown]
# ### Elderly Population (65 and above)

# %%
population = pd.read_excel('../data/Philippine Population 2020 by Province and Age Group.xlsx', index_col=0)
population.head()
# Out:
#                                 0 to 4  5 to 9  10 to 14  15 to 19  20 to 24  \
# BASILAN                          63979   61636     56582     45050     40105
# COTABATO CITY (NOT A PROVINCE)   38216   35974     34523     35957     36567
# LANAO DEL SUR                   182925  160576    156233    137554    123810
# MAGUINDANAO                     223251  193100    179050    138736    124325
# SULU                            130431  135390    130518    122121    100731
#
#                                 25 to 29  30 to 34  35 to 39  40 to 44  \
# BASILAN                            34417     27226     23655     19508
# COTABATO CITY (NOT A PROVINCE)     32404     24889     20741     17727
# LANAO DEL SUR                     101418     75871     63633     55861
# MAGUINDANAO                       106176     89110     76435     66797
# SULU                               84344     62854     58477     50591
#
#                                 45 to 49  50 to 54  55 to 59  60 to 64  \
# BASILAN                            16292     12212      8616      6256
# COTABATO CITY (NOT A PROVINCE)     13937     10973      7678      5916
# LANAO DEL SUR                      44624     32651     20800     15346
# MAGUINDANAO                        50553     34625     22091     15534
# SULU                               42671     28650     18751     13046
#
#                                 65 to 69  70 to 74  75 to 79   80+
# BASILAN                             4528      2411      1320  1318
# COTABATO CITY (NOT A PROVINCE)      3891      2535      1239  1372
# LANAO DEL SUR                      10967      5999      3125  3114
# MAGUINDANAO                        10130      5886      3036  2979
# SULU                                9290      5469      2727  2614

# %%
province_total = population.sum(axis=1)
province_total
# Out:
# BASILAN                            425111
# COTABATO CITY (NOT A PROVINCE)     324539
# LANAO DEL SUR                     1194507
# MAGUINDANAO                       1341814
# SULU                               998675
#                                    ...
# DAVAO ORIENTAL                     574984
# COTABATO (NORTH COTABATO)         1273594
# SARANGANI                          558069
# SOUTH COTABATO                    1668556
# SULTAN KUDARAT                     851554
# Length: 85, dtype: int64

# %%
province_elderly = population[['65 to 69', '70 to 74', '75 to 79', '80+']].sum(axis=1)
province_elderly
# Out:
# BASILAN                            9577
# COTABATO CITY (NOT A PROVINCE)     9037
# LANAO DEL SUR                     23205
# MAGUINDANAO                       22031
# SULU                              20100
#                                   ...
# DAVAO ORIENTAL                    32292
# COTABATO (NORTH COTABATO)         61877
# SARANGANI                         22037
# SOUTH COTABATO                    72462
# SULTAN KUDARAT                    35687
# Length: 85, dtype: int64

# %%
elderly = province_elderly / province_total * 100
elderly
# Out:
# BASILAN                           2.252823
# COTABATO CITY (NOT A PROVINCE)    2.784565
# LANAO DEL SUR                     1.942642
# MAGUINDANAO                       1.641882
# SULU                              2.012667
#                                     ...
# DAVAO ORIENTAL                    5.616156
# COTABATO (NORTH COTABATO)         4.858456
# SARANGANI                         3.948795
# SOUTH COTABATO                    4.342797
# SULTAN KUDARAT                    4.190809
# Length: 85, dtype: float64

# %%
elderly = elderly.reset_index().rename(columns={'index': 'PROVINCE', 0: 'Elderly (65 and above) % (2020)'}).set_index('PROVINCE')
elderly
# Out:
#                                 Elderly (65 and above) % (2020)
# PROVINCE
# BASILAN                                                2.252823
# COTABATO CITY (NOT A PROVINCE)                         2.784565
# LANAO DEL SUR                                          1.942642
# MAGUINDANAO                                            1.641882
# SULU                                                   2.012667
# ...                                                         ...
# DAVAO ORIENTAL                                         5.616156
# COTABATO (NORTH COTABATO)                              4.858456
# SARANGANI                                              3.948795
# SOUTH COTABATO                                         4.342797
# SULTAN KUDARAT                                         4.190809
#
# [85 rows x 1 columns]

# %%
elderly.to_excel('../data/Elderly Percentage (2020).xlsx')

# %%
# Dropping Interim Province 
elderly = elderly.drop('INTERIM PROVINCE')
elderly
# Out:
#                                 Elderly (65 and above) % (2020)
# PROVINCE
# BASILAN                                                2.252823
# COTABATO CITY (NOT A PROVINCE)                         2.784565
# LANAO DEL SUR                                          1.942642
# MAGUINDANAO                                            1.641882
# SULU                                                   2.012667
# ...                                                         ...
# DAVAO ORIENTAL                                         5.616156
# COTABATO (NORTH COTABATO)                              4.858456
# SARANGANI                                              3.948795
# SOUTH COTABATO                                         4.342797
# SULTAN KUDARAT                                         4.190809
#
# [84 rows x 1 columns]

# %% [markdown]
# ### COVID-19 Tests Performed

# %%
tests = "/Users/jimuelcelestejr/Documents/codebook/covid-asmr-philippines/data/COVID-19 Tests/tests_by_province_per_100k.csv"
tests = pd.read_csv(tests, index_col=0)
tests.head()
# Out:
#                                 Population  Cumulative Samples Tested  \
# PROVINCE
# BASILAN                             425111                        0.0
# COTABATO CITY (NOT A PROVINCE)      324539                   304663.0
# LANAO DEL SUR                      1194507                    83750.0
# MAGUINDANAO                        1341814                      923.0
# SULU                                998675                        0.0
#
#                                 Tests / Population  \
# PROVINCE
# BASILAN                                   0.000000
# COTABATO CITY (NOT A PROVINCE)            0.938756
# LANAO DEL SUR                             0.070113
# MAGUINDANAO                               0.000688
# SULU                                      0.000000
#
#                                 Tests / Population per 100k (2019-2023)
# PROVINCE
# BASILAN                                                        0.000000
# COTABATO CITY (NOT A PROVINCE)                             93875.620496
# LANAO DEL SUR                                               7011.260713
# MAGUINDANAO                                                   68.787477
# SULU                                                           0.000000

# %%
tests = tests['Tests / Population per 100k (2019-2023)']
tests = tests.reset_index()
tests = tests.rename(columns={"Tests / Population per 100k (2019-2023)": "COVID-19 Tests per 100k (2019-23)"})
tests = tests.set_index("PROVINCE")
tests
# Out:
#                                 COVID-19 Tests per 100k (2019-23)
# PROVINCE
# BASILAN                                                  0.000000
# COTABATO CITY (NOT A PROVINCE)                       93875.620496
# LANAO DEL SUR                                         7011.260713
# MAGUINDANAO                                             68.787477
# SULU                                                     0.000000
# ...                                                           ...
# DAVAO ORIENTAL                                           0.000000
# COTABATO (NORTH COTABATO)                              310.145933
# SARANGANI                                                0.000000
# SOUTH COTABATO                                        8447.783593
# SULTAN KUDARAT                                        3327.680922
#
# [85 rows x 1 columns]

# %% [markdown]
# ### Crude and Age-Standardized Mortality Rates

# %%
mr = pd.read_excel('../results/province_CMR and ASMR per 100 000 by Province.xlsx')
mr = mr.rename(columns={
    'Unnamed: 0': 'PROVINCE',
    'crude_mortality_rate_per_100k': 'CMR', 
    'age_standardized_mortality_rate_per_100k': 'ASMR', 
    'difference': 'Difference (CMR-ASMR)'})
mr = mr.set_index('PROVINCE')
mr = mr.drop(['mortality', 'population'], axis=1)
mr.head()
# Out:
#                          CMR      ASMR  Difference (CMR-ASMR)
# PROVINCE
# TAWI-TAWI           1.368161  2.221281              -0.853120
# SULU                1.401857  2.628742              -1.226885
# MASBATE             4.411452  4.819455              -0.408003
# MISAMIS OCCIDENTAL  9.594260  7.720111               1.874149
# CAMARINES NORTE     8.587691  8.697143              -0.109453

# %%
mr.shape
# Out:
# (84, 3)

# %% [markdown]
# ### Merged Dataset

# %%
datasets = [poverty, beds, density, elderly, tests]
for dataset in datasets:
    mr = mr.merge(dataset, how='outer', on='PROVINCE')
mr.head()
# Out:
#                          CMR      ASMR  Difference (CMR-ASMR)  \
# PROVINCE
# TAWI-TAWI           1.368161  2.221281              -0.853120
# SULU                1.401857  2.628742              -1.226885
# MASBATE             4.411452  4.819455              -0.408003
# MISAMIS OCCIDENTAL  9.594260  7.720111               1.874149
# CAMARINES NORTE     8.587691  8.697143              -0.109453
#
#                     Poverty Incidence (2021)  Hospital Beds per 100k (2022)  \
# PROVINCE
# TAWI-TAWI                               36.5                      43.325086
# SULU                                    62.5                      25.033169
# MASBATE                                 27.7                      15.991512
# MISAMIS OCCIDENTAL                      24.7                     148.629728
# CAMARINES NORTE                         22.2                      77.607279
#
#                     Population Density (2020)  \
# PROVINCE
# TAWI-TAWI                          121.403538
# SULU                               219.941238
# MASBATE                            219.622284
# MISAMIS OCCIDENTAL                 307.646651
# CAMARINES NORTE                    276.434746
#
#                     Elderly (65 and above) % (2020)  \
# PROVINCE
# TAWI-TAWI                                  2.235802
# SULU                                       2.012667
# MASBATE                                    5.321093
# MISAMIS OCCIDENTAL                         7.135040
# CAMARINES NORTE                            5.485626
#
#                     COVID-19 Tests per 100k (2019-23)
# PROVINCE
# TAWI-TAWI                                    0.000000
# SULU                                         0.000000
# MASBATE                                      0.000000
# MISAMIS OCCIDENTAL                        4291.561441
# CAMARINES NORTE                              0.000000

# %%
mr.index
# Out:
# Index(['TAWI-TAWI', 'SULU', 'MASBATE', 'MISAMIS OCCIDENTAL', 'CAMARINES NORTE',
#        'SARANGANI', 'CAMIGUIN', 'SULTAN KUDARAT', 'SOUTHERN LEYTE',
#        'CATANDUANES', 'BATANES', 'EASTERN SAMAR', 'NORTHERN SAMAR', 'BUKIDNON',
#        'COTABATO (NORTH COTABATO)', 'SORSOGON', 'LEYTE',
#        'SAMAR (WESTERN SAMAR)', 'BASILAN', 'QUEZON', 'MAGUINDANAO',
#        'ZAMBOANGA SIBUGAY', 'ROMBLON', 'ALBAY', 'CAMARINES SUR',
#        'ZAMBOANGA DEL NORTE', 'SIQUIJOR', 'BILIRAN', 'MISAMIS ORIENTAL',
#        'BOHOL', 'AKLAN', 'MARINDUQUE', 'ILOCOS SUR', 'PALAWAN', 'BATANGAS',
#        'DAVAO OCCIDENTAL', 'CAVITE', 'OCCIDENTAL MINDORO', 'LANAO DEL SUR',
#        'ANTIQUE', 'LANAO DEL NORTE', 'DINAGAT ISLANDS', 'NEGROS ORIENTAL',
#        'CAPIZ', 'ABRA', 'PANGASINAN', 'AGUSAN DEL SUR', 'LAGUNA',
#        'DAVAO ORIENTAL', 'NUEVA ECIJA', 'ORIENTAL MINDORO', 'TARLAC',
#        'ZAMBOANGA DEL SUR', 'CITY OF ISABELA (NOT A PROVINCE)', 'DAVAO DE ORO',
#        'ILOCOS NORTE', 'BULACAN', 'RIZAL', 'SURIGAO DEL NORTE', 'LA UNION',
#        'ILOILO', 'SURIGAO DEL SUR', 'NEGROS OCCIDENTAL', 'PAMPANGA', 'IFUGAO',
#        'SOUTH COTABATO', 'AGUSAN DEL NORTE', 'COTABATO CITY (NOT A PROVINCE)',
#        'ZAMBALES', 'MOUNTAIN PROVINCE', 'DAVAO DEL NORTE', 'GUIMARAS',
#        'KALINGA', 'APAYAO', 'DAVAO DEL SUR', 'AURORA', 'CEBU', 'ISABELA',
#        'NCR', 'QUIRINO', 'NUEVA VIZCAYA', 'BATAAN', 'CAGAYAN', 'BENGUET',
#        'INTERIM PROVINCE'],
#       dtype='object', name='PROVINCE')

# %%
mr = mr.drop('INTERIM PROVINCE')
mr
# Out:
#                            CMR        ASMR  Difference (CMR-ASMR)  \
# PROVINCE
# TAWI-TAWI             1.368161    2.221281              -0.853120
# SULU                  1.401857    2.628742              -1.226885
# MASBATE               4.411452    4.819455              -0.408003
# MISAMIS OCCIDENTAL    9.594260    7.720111               1.874149
# CAMARINES NORTE       8.587691    8.697143              -0.109453
# ...                        ...         ...                    ...
# QUIRINO             118.901390  115.119705               3.781686
# NUEVA VIZCAYA       132.314025  121.070666              11.243359
# BATAAN              136.303446  137.883440              -1.579994
# CAGAYAN             163.171453  139.275997              23.895456
# BENGUET             211.033297  207.832506               3.200791
#
#                     Poverty Incidence (2021)  Hospital Beds per 100k (2022)  \
# PROVINCE
# TAWI-TAWI                               36.5                      43.325086
# SULU                                    62.5                      25.033169
# MASBATE                                 27.7                      15.991512
# MISAMIS OCCIDENTAL                      24.7                     148.629728
# CAMARINES NORTE                         22.2                      77.607279
# ...                                      ...                            ...
# QUIRINO                                  9.1                      92.861003
# NUEVA VIZCAYA                           15.3                     142.182195
# BATAAN                                  11.6                     118.176735
# CAGAYAN                                 10.1                     114.180508
# BENGUET                                  5.6                     156.451529
#
#                     Population Density (2020)  \
# PROVINCE
# TAWI-TAWI                          121.403538
# SULU                               219.941238
# MASBATE                            219.622284
# MISAMIS OCCIDENTAL                 307.646651
# CAMARINES NORTE                    276.434746
# ...                                       ...
# QUIRINO                             87.869774
# NUEVA VIZCAYA                      103.332862
# BATAAN                             621.548020
# CAGAYAN                            134.985481
# BENGUET                            292.593195
#
#                     Elderly (65 and above) % (2020)  \
# PROVINCE
# TAWI-TAWI                                  2.235802
# SULU                                       2.012667
# MASBATE                                    5.321093
# MISAMIS OCCIDENTAL                         7.135040
# CAMARINES NORTE                            5.485626
# ...                                             ...
# QUIRINO                                    5.531371
# NUEVA VIZCAYA                              6.116855
# BATAAN                                     5.305829
# CAGAYAN                                    6.684182
# BENGUET                                    5.339045
#
#                     COVID-19 Tests per 100k (2019-23)
# PROVINCE
# TAWI-TAWI                                    0.000000
# SULU                                         0.000000
# MASBATE                                      0.000000
# MISAMIS OCCIDENTAL                        4291.561441
# CAMARINES NORTE                              0.000000
# ...                                               ...
# QUIRINO                                      0.000000
# NUEVA VIZCAYA                                0.000000
# BATAAN                                   34312.214931
# CAGAYAN                                  36449.025712
# BENGUET                                 113820.371278
#
# [84 rows x 8 columns]

# %%
mr.shape
# Out:
# (84, 8)

# %% [markdown]
# 82 provinces + 2 cities

# %%
output_file = '/Users/jimuelcelestejr/Documents/codebook/covid-asmr-philippines/data/correlation_analysis.csv'
mr.to_csv(output_file)

# %% [markdown]
# ## Spearman's Rank Correlation Coefficient
#
# "For nonnormally distributed continuous data, for ordinal data, **or for data with relevant outliers**, a Spearman rank correlation can be used as a measure of a monotonic association ([Schober et al., 2018](https://www.doi.org/10.1213/ANE.0000000000002864))."

# %%
correlation = mr.corr(method='spearman')
correlation
# Out:
#                                         CMR      ASMR  Difference (CMR-ASMR)  \
# CMR                                1.000000  0.965050               0.369242
# ASMR                               0.965050  1.000000               0.153204
# Difference (CMR-ASMR)              0.369242  0.153204               1.000000
# Poverty Incidence (2021)          -0.547969 -0.491047              -0.302319
# Hospital Beds per 100k (2022)      0.347173  0.334705               0.134209
# Population Density (2020)          0.097074  0.111329              -0.122952
# Elderly (65 and above) % (2020)    0.211299 -0.005406               0.904890
# COVID-19 Tests per 100k (2019-23)  0.435921  0.461353              -0.005293
#
#                                    Poverty Incidence (2021)  \
# CMR                                               -0.547969
# ASMR                                              -0.491047
# Difference (CMR-ASMR)                             -0.302319
# Poverty Incidence (2021)                           1.000000
# Hospital Beds per 100k (2022)                     -0.448287
# Population Density (2020)                         -0.288377
# Elderly (65 and above) % (2020)                   -0.250804
# COVID-19 Tests per 100k (2019-23)                 -0.347366
#
#                                    Hospital Beds per 100k (2022)  \
# CMR                                                     0.347173
# ASMR                                                    0.334705
# Difference (CMR-ASMR)                                   0.134209
# Poverty Incidence (2021)                               -0.448287
# Hospital Beds per 100k (2022)                           1.000000
# Population Density (2020)                               0.315562
# Elderly (65 and above) % (2020)                         0.151841
# COVID-19 Tests per 100k (2019-23)                       0.520935
#
#                                    Population Density (2020)  \
# CMR                                                 0.097074
# ASMR                                                0.111329
# Difference (CMR-ASMR)                              -0.122952
# Poverty Incidence (2021)                           -0.288377
# Hospital Beds per 100k (2022)                       0.315562
# Population Density (2020)                           1.000000
# Elderly (65 and above) % (2020)                    -0.003868
# COVID-19 Tests per 100k (2019-23)                   0.517530
#
#                                    Elderly (65 and above) % (2020)  \
# CMR                                                       0.211299
# ASMR                                                     -0.005406
# Difference (CMR-ASMR)                                     0.904890
# Poverty Incidence (2021)                                 -0.250804
# Hospital Beds per 100k (2022)                             0.151841
# Population Density (2020)                                -0.003868
# Elderly (65 and above) % (2020)                           1.000000
# COVID-19 Tests per 100k (2019-23)                        -0.014217
#
#                                    COVID-19 Tests per 100k (2019-23)
# CMR                                                         0.435921
# ASMR                                                        0.461353
# Difference (CMR-ASMR)                                      -0.005293
# Poverty Incidence (2021)                                   -0.347366
# Hospital Beds per 100k (2022)                               0.520935
# Population Density (2020)                                   0.517530
# Elderly (65 and above) % (2020)                            -0.014217
# COVID-19 Tests per 100k (2019-23)                           1.000000

# %%
correlation.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_0a85d_row0_col0, #T_0a85d_row1_col1, #T_0a85d_row2_col2, #T_0a85d_row3_col3, #T_0a85d_row4_col4, #T_0a85d_row5_col5, #T_0a85d_row6_col6, #T_0a85d_row7_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0a85d_row0_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_0a85d_row0_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_0a85d_row0_col3, #T_0a85d_row3_col0, #T_0a85d_row3_col1, #T_0a85d_row3_col2, #T_0a85d_row3_col4, #T_0a85d_row3_col5, #T_0a85d_row3_col6, #T_0a85d_row3_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0a85d_row0_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_0a85d_row0_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_0a85d_row0_col6 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_0a85d_row0_col7, #T_0a85d_row4_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_0a85d_row1_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_0a85d_row1_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_0a85d_row1_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0a85d_row1_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_0a85d_row1_col5 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_0a85d_row1_col6, #T_0a85d_row5_col6 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_0a85d_row1_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_0a85d_row2_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_0a85d_row2_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_0a85d_row2_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_0a85d_row2_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_0a85d_row2_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_0a85d_row2_col6 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_0a85d_row2_col7 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_0a85d_row4_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_0a85d_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_0a85d_row4_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_0a85d_row4_col5 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_0a85d_row4_col6 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_0a85d_row4_col7, #T_0a85d_row5_col7 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_0a85d_row5_col0, #T_0a85d_row6_col4 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_0a85d_row5_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_0a85d_row5_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_0a85d_row5_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_0a85d_row5_col4 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_0a85d_row6_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_0a85d_row6_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_0a85d_row6_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_0a85d_row6_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_0a85d_row6_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_0a85d_row6_col7 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_0a85d_row7_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_0a85d_row7_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_0a85d_row7_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_0a85d_row7_col3 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0a85d_row7_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_0a85d_row7_col5 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_0a85d_row7_col6 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_0a85d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a85d_level0_col0" class="col_heading level0 col0" >CMR</th>
#       <th id="T_0a85d_level0_col1" class="col_heading level0 col1" >ASMR</th>
#       <th id="T_0a85d_level0_col2" class="col_heading level0 col2" >Difference (CMR-ASMR)</th>
#       <th id="T_0a85d_level0_col3" class="col_heading level0 col3" >Poverty Incidence (2021)</th>
#       <th id="T_0a85d_level0_col4" class="col_heading level0 col4" >Hospital Beds per 100k (2022)</th>
#       <th id="T_0a85d_level0_col5" class="col_heading level0 col5" >Population Density (2020)</th>
#       <th id="T_0a85d_level0_col6" class="col_heading level0 col6" >Elderly (65 and above) % (2020)</th>
#       <th id="T_0a85d_level0_col7" class="col_heading level0 col7" >COVID-19 Tests per 100k (2019-23)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a85d_level0_row0" class="row_heading level0 row0" >CMR</th>
#       <td id="T_0a85d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0a85d_row0_col1" class="data row0 col1" >0.965050</td>
#       <td id="T_0a85d_row0_col2" class="data row0 col2" >0.369242</td>
#       <td id="T_0a85d_row0_col3" class="data row0 col3" >-0.547969</td>
#       <td id="T_0a85d_row0_col4" class="data row0 col4" >0.347173</td>
#       <td id="T_0a85d_row0_col5" class="data row0 col5" >0.097074</td>
#       <td id="T_0a85d_row0_col6" class="data row0 col6" >0.211299</td>
#       <td id="T_0a85d_row0_col7" class="data row0 col7" >0.435921</td>
#     </tr>
#     <tr>
#       <th id="T_0a85d_level0_row1" class="row_heading level0 row1" >ASMR</th>
#       <td id="T_0a85d_row1_col0" class="data row1 col0" >0.965050</td>
#       <td id="T_0a85d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0a85d_row1_col2" class="data row1 col2" >0.153204</td>
#       <td id="T_0a85d_row1_col3" class="data row1 col3" >-0.491047</td>
#       <td id="T_0a85d_row1_col4" class="data row1 col4" >0.334705</td>
#       <td id="T_0a85d_row1_col5" class="data row1 col5" >0.111329</td>
#       <td id="T_0a85d_row1_col6" class="data row1 col6" >-0.005406</td>
#       <td id="T_0a85d_row1_col7" class="data row1 col7" >0.461353</td>
#     </tr>
#     <tr>
#       <th id="T_0a85d_level0_row2" class="row_heading level0 row2" >Difference (CMR-ASMR)</th>
#       <td id="T_0a85d_row2_col0" class="data row2 col0" >0.369242</td>
#       <td id="T_0a85d_row2_col1" class="data row2 col1" >0.153204</td>
#       <td id="T_0a85d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0a85d_row2_col3" class="data row2 col3" >-0.302319</td>
#       <td id="T_0a85d_row2_col4" class="data row2 col4" >0.134209</td>
#       <td id="T_0a85d_row2_col5" class="data row2 col5" >-0.122952</td>
#       <td id="T_0a85d_row2_col6" class="data row2 col6" >0.904890</td>
#       <td id="T_0a85d_row2_col7" class="data row2 col7" >-0.005293</td>
#     </tr>
#     <tr>
#       <th id="T_0a85d_level0_row3" class="row_heading level0 row3" >Poverty Incidence (2021)</th>
#       <td id="T_0a85d_row3_col0" class="data row3 col0" >-0.547969</td>
#       <td id="T_0a85d_row3_col1" class="data row3 col1" >-0.491047</td>
#       <td id="T_0a85d_row3_col2" class="data row3 col2" >-0.302319</td>
#       <td id="T_0a85d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0a85d_row3_col4" class="data row3 col4" >-0.448287</td>
#       <td id="T_0a85d_row3_col5" class="data row3 col5" >-0.288377</td>
#       <td id="T_0a85d_row3_col6" class="data row3 col6" >-0.250804</td>
#       <td id="T_0a85d_row3_col7" class="data row3 col7" >-0.347366</td>
#     </tr>
#     <tr>
#       <th id="T_0a85d_level0_row4" class="row_heading level0 row4" >Hospital Beds per 100k (2022)</th>
#       <td id="T_0a85d_row4_col0" class="data row4 col0" >0.347173</td>
#       <td id="T_0a85d_row4_col1" class="data row4 col1" >0.334705</td>
#       <td id="T_0a85d_row4_col2" class="data row4 col2" >0.134209</td>
#       <td id="T_0a85d_row4_col3" class="data row4 col3" >-0.448287</td>
#       <td id="T_0a85d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0a85d_row4_col5" class="data row4 col5" >0.315562</td>
#       <td id="T_0a85d_row4_col6" class="data row4 col6" >0.151841</td>
#       <td id="T_0a85d_row4_col7" class="data row4 col7" >0.520935</td>
#     </tr>
#     <tr>
#       <th id="T_0a85d_level0_row5" class="row_heading level0 row5" >Population Density (2020)</th>

# %%
for row in mr.columns:
    for col in mr.columns:
        plt.figure() 
        sns.regplot(data=mr, x=row, y=col, ci=None)
        plt.savefig("../results/correlation_v2/%s-%s.png" % (row, col), bbox_inches ="tight")
# Out:
# /var/folders/ny/jv8cwgpx7ng41dfgnqsvzdnw0000gn/T/ipykernel_26960/779438660.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
# Reference: https://seaborn.pydata.org/tutorial/axis_grids.html
g = sns.pairplot(mr, corner=True, diag_kind="kde", height=2.25)
# g = sns.PairGrid(mr, corner=True)
# g.map_diag(sns.histplot)
g.map_offdiag(sns.regplot, ci=None)

# Reference: https://stackoverflow.com/questions/39961147/how-to-align-y-labels-in-a-seaborn-pairgrid
for ax in g.axes[:,0]:
    ax.get_yaxis().set_label_coords(-0.3,0.5)

# Saving Figure 
plt.savefig("../results/correlation_v2/correlation_pairplot.png", bbox_inches ="tight")

# %%
# Compute the correlation matrix
corr = correlation

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots()#figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.savefig("../results/correlation_v2/correlation_heatmap.png", bbox_inches ="tight")

# %%
# g = sns.pairplot(mr, diag_kind="kde", corner=True, height=2)
# g.map_lower(sns.regplot, ci=None)

g = sns.pairplot(
    mr,
    x_vars=["Poverty Incidence (2021)", "Population Density (2020)", "Hospital Beds per 100k (2022)", "Elderly (65 and above) % (2020)"],
    y_vars=["CMR", "ASMR", "Difference (CMR-ASMR)"], 
    height=2.5
)
g.map(sns.regplot, ci=None)

# Reference: https://stackoverflow.com/questions/39961147/how-to-align-y-labels-in-a-seaborn-pairgrid
for ax in g.axes[:,0]:
    ax.get_yaxis().set_label_coords(-0.3,0.5)

# Saving Figure 
plt.savefig("../results/correlation_v2/correlation_subset.png", bbox_inches ="tight")

# %%
# g = sns.pairplot(mr, diag_kind="kde", corner=True, height=2)
# g.map_lower(sns.regplot, ci=None)
				
g = sns.pairplot(
    mr,
    x_vars=["Poverty Incidence (2021)", "Population Density (2020)", "Hospital Beds per 100k (2022)", "Elderly (65 and above) % (2020)"],
    y_vars=["Poverty Incidence (2021)", "Population Density (2020)", "Hospital Beds per 100k (2022)", "Elderly (65 and above) % (2020)"], 
    height=2.5
)
g.map(sns.regplot, ci=None)

# Reference: https://stackoverflow.com/questions/39961147/how-to-align-y-labels-in-a-seaborn-pairgrid
for ax in g.axes[:,0]:
    ax.get_yaxis().set_label_coords(-0.3,0.5)

# Saving Figure 
plt.savefig("../results/correlation_v2/correlation_subset_predictors.png", bbox_inches ="tight")

# %%
correlation.to_excel('../results/correlation_v2/spearman_correlation.xlsx')

# %% [markdown]
# ### P-Values

# %%
# https://www.statology.org/p-value-correlation-pandas/
def r_pvalues(df):
    cols = pd.DataFrame(columns=df.columns)
    p = cols.transpose().join(cols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            p[r][c] = round(stats.pearsonr(tmp[r], tmp[c])[1], 4)
    return p

# %%
p = r_pvalues(mr)
p
# Out:
#                                       CMR    ASMR Difference (CMR-ASMR)  \
# CMR                                   0.0     0.0                0.0007
# ASMR                                  0.0     0.0                0.1946
# Difference (CMR-ASMR)              0.0007  0.1946                   0.0
# Poverty Incidence (2021)              0.0     0.0                0.0024
# Hospital Beds per 100k (2022)      0.0107  0.0089                0.6856
# Population Density (2020)          0.2036  0.0813                0.1094
# Elderly (65 and above) % (2020)    0.1087  0.9617                   0.0
# COVID-19 Tests per 100k (2019-23)     0.0     0.0                0.4036
#
#                                   Poverty Incidence (2021)  \
# CMR                                                    0.0
# ASMR                                                   0.0
# Difference (CMR-ASMR)                               0.0024
# Poverty Incidence (2021)                               0.0
# Hospital Beds per 100k (2022)                          0.0
# Population Density (2020)                           0.0462
# Elderly (65 and above) % (2020)                     0.0004
# COVID-19 Tests per 100k (2019-23)                   0.0066
#
#                                   Hospital Beds per 100k (2022)  \
# CMR                                                      0.0107
# ASMR                                                     0.0089
# Difference (CMR-ASMR)                                    0.6856
# Poverty Incidence (2021)                                    0.0
# Hospital Beds per 100k (2022)                               0.0
# Population Density (2020)                                0.0104
# Elderly (65 and above) % (2020)                          0.0416
# COVID-19 Tests per 100k (2019-23)                           0.0
#
#                                   Population Density (2020)  \
# CMR                                                  0.2036
# ASMR                                                 0.0813
# Difference (CMR-ASMR)                                0.1094
# Poverty Incidence (2021)                             0.0462
# Hospital Beds per 100k (2022)                        0.0104
# Population Density (2020)                               0.0
# Elderly (65 and above) % (2020)                      0.3379
# COVID-19 Tests per 100k (2019-23)                       0.0
#
#                                   Elderly (65 and above) % (2020)  \
# CMR                                                        0.1087
# ASMR                                                       0.9617
# Difference (CMR-ASMR)                                         0.0
# Poverty Incidence (2021)                                   0.0004
# Hospital Beds per 100k (2022)                              0.0416
# Population Density (2020)                                  0.3379
# Elderly (65 and above) % (2020)                               0.0
# COVID-19 Tests per 100k (2019-23)                           0.543
#
#                                   COVID-19 Tests per 100k (2019-23)
# CMR                                                             0.0
# ASMR                                                            0.0
# Difference (CMR-ASMR)                                        0.4036
# Poverty Incidence (2021)                                     0.0066
# Hospital Beds per 100k (2022)                                   0.0
# Population Density (2020)                                       0.0
# Elderly (65 and above) % (2020)                               0.543
# COVID-19 Tests per 100k (2019-23)                               0.0

# %%
p.to_excel('../results/correlation_v2/p-values.xlsx')
